# %%
import torchaudio
from speechbrain.pretrained import SpectralMaskEnhancement
from IPython.display import display, Audio

# %%
# Model is downloaded from the speechbrain HuggingFace repo
tmpdir = "results"
enhancer = SpectralMaskEnhancement.from_hparams(
    source="speechbrain/mtl-mimic-voicebank",
    savedir=tmpdir,
)
noisy, fs = torchaudio.load("/Users/ccui/Desktop/AMI_sample/clips_synthesis_8array1_align/sample391/mixture_mic4.wav")
# Channel dimension is interpreted as batch dimension here
enhanced = enhancer.enhance_batch(noisy)

# %%
display(Audio(enhanced,rate=16000))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ex_1731_s1, fs = torchaudio.load("/Users/ccui/Desktop/asteroid/egs/AMIx/TAC/exp/snr_data_clips_synthesis_3array1_st4k_a_bs4_epo100_3cc531ab/examples/ex_1731/s1_estimate.wav")
ex_1731_s2, fs = torchaudio.load("/Users/ccui/Desktop/asteroid/egs/AMIx/TAC/exp/snr_data_clips_synthesis_3array1_st4k_a_bs4_epo100_3cc531ab/examples/ex_1731/s2_estimate.wav")
for ex in [ex_1731_s1,ex_1731_s2]:
    print('Before enhencement')
    display(Audio(ex,rate=16000))
    enhanced = enhancer.enhance_batch(ex)
    print('After enhencement')
    display(Audio(enhanced,rate=16000))
# Out:
# Before enhencement
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# After enhencement
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Before enhencement
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# After enhencement
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ex_1890_s1, fs = torchaudio.load("/Users/ccui/Desktop/asteroid/egs/AMIx/TAC/exp/snr_data_clips_synthesis_3array1_st4k_a_bs4_epo100_3cc531ab/examples/ex_1890/s1_estimate.wav")
ex_1890_s2, fs = torchaudio.load("/Users/ccui/Desktop/asteroid/egs/AMIx/TAC/exp/snr_data_clips_synthesis_3array1_st4k_a_bs4_epo100_3cc531ab/examples/ex_1890/s2_estimate.wav")
for ex in [ex_1890_s1,ex_1890_s2]:
    print('Before enhencement')
    display(Audio(ex,rate=16000))
    enhanced = enhancer.enhance_batch(ex)
    print('After enhencement')
    display(Audio(enhanced,rate=16000))
# Out:
# Before enhencement
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# After enhencement
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Before enhencement
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# After enhencement
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
